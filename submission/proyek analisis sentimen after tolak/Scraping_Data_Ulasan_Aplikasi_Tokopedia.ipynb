# %% [markdown]
# # Import Library

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
seed = 0
np.random.seed(seed)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scraping Dataset

# %%
scrapreview = reviews_all(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10000
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
  writer = csv.writer(file)
  writer.writerow(['Review']) # Menulis header kolom
  for review in scrapreview:
    writer.writerow([review['content']]) # menulis konten ulasan ke dalam file CSV

# %% [markdown]
# # Loading Dataset

# %%
tkpd_review_df = pd.DataFrame(scrapreview)
tkpd_review_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
tkpd_review_df.shape
# Out:
# (184500, 11)

# %%
tkpd_review_df.head()
# Out:
#                                reviewId         userName  \
# 0  c4d64638-5f79-470d-a6d7-3510c5b44648  Pengguna Google
# 1  9faf326c-e252-468c-b283-19ea0bac9f3c  Pengguna Google
# 2  535c5471-1574-4053-a7a4-79ab27ae6f57  Pengguna Google
# 3  c8ab50e4-aca7-4498-9ccd-07d7fc5481cf  Pengguna Google
# 4  98a606a6-be4f-4d28-bfe6-0f68cd27c445  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi Payah.. Baru Pertama Pakai Tokopedia ...      2             46
# 1  Setelah di beli tiktok, tokopedia jadi ancur, ...      1             52
# 2  Salah satu aplikasi yang untuk hobi barangnya ...      4             12
# 3  bintang satu gan, hati2 transaksi di aplikasi ...      1             11
# 4  Kok otomatis bisa menyalurkan uang ke penjual ...      1             59
#
#   reviewCreatedVersion                  at  \
# 0              3.305.0 2025-04-07 02:55:19
# 1              3.305.0 2025-04-04 18:13:01
# 2              3.305.0 2025-04-09 05:41:59
# 3              3.305.0 2025-04-11 03:01:49
# 4              3.305.0 2025-03-29 16:34:08
#
#                                         replyContent           repliedAt  \
# 0  Hi Toppers, silakan sampaikan kritik/saran ata... 2025-04-07 03:27:03
# 1  Halo Toppers, terima kasih atas rating yang ka... 2025-04-04 18:47:03
# 2  Toppers, terima kasih atas rating yang kamu be... 2025-04-09 06:07:01
# 3  Hi Toppers, silakan sampaikan kritik/saran ata... 2025-04-11 03:27:05
# 4  Halo Toppers, terima kasih atas rating yang ka... 2025-03-29 17:07:02
#
#   appVersion
# 0    3.305.0
# 1    3.305.0
# 2    3.305.0
# 3    3.305.0
# 4    3.305.0
